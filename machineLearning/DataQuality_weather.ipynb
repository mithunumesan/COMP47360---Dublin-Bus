# %%
import pandas as pd
import datetime as dt
from matplotlib import pyplot as plt

# %% [markdown]
# # Explain the meaning of each FEATURE

# %% [markdown]
# - dt : Data calculation time
# - dt_iso
# - timezone : time zone
# - city_name : city name
# - lat :latitude
# - lon :Longitude
# - temp :temperature
# - visibility :visibility
# - dew_point :dew point
# - feels_like :This temperature parameter describes the human perception of the weather. Default units. Kelvin, metric. Celsius, imperial. Fahrenheit (Fahrenheit)
# - temp_min :minimum_temperature
# - temp_max :maximum temperature
# - pressure :pressure
# - sea_level :Atmospheric pressure at sea level,, hPa
# - grnd_level :Atmospheric pressure at ground level, hPa
# - humidity :humidity
# - wind_speed :wind speed
# - wind_deg :wind direction in degrees (meteorology)
# - wind_gust :last update time
# - rain_1h :Rainfall for the last 1 hour
# - rain_3h :amount of rain in the last 3 hours
# - snow_1h :amount of snow in the last 1 hour
# - snow_3h :last update time
# - clouds_all :% turbidity %
# - weather_id :Weather condition identifier
# - weather_main :Main weather conditions
# - weather_description :Weather description
# - weather_icon :Weather icon ID

# %% [markdown]
# ### Summary of data quality plan:
# | Variable Names                     | Data Quality Issue            | Handling Strategy              |
# |------------------------------------|-------------------------------|--------------------------------|
# | dt_iso  | Presence of data other than 2018 | Delete data other than 2018 |
# | dt_iso  | Duplicate time | Delete data other than 2018 |
# | dt_iso  | Name not clear enough | Change name to day_hour |
# | snow_1h         | high %missing value | no action |
# | city_name     | constant column | delete |
# | lat              | constant column | delete |
# | lon   | constant column | delete |
# | sea_level | constant column | delete |
# | grnd_level                                            | constant column | delete |
# | rain_3h                                            | constant column | delete |
# | snow_3h                                            | constant column | delete |
# | rain_1h                                            | %missing higher |delete |
# | snow_1h                                           | %missing higher |delete |

# %%
df= pd.read_csv("historyWeatherDublin2018.csv")

# %%
df.head(5)
# Out:
#            dt                         dt_iso  timezone        city_name  \
# 0  1483228800  2017-01-01 00:00:00 +0000 UTC         0  Custom location
# 1  1483232400  2017-01-01 01:00:00 +0000 UTC         0  Custom location
# 2  1483236000  2017-01-01 02:00:00 +0000 UTC         0  Custom location
# 3  1483239600  2017-01-01 03:00:00 +0000 UTC         0  Custom location
# 4  1483243200  2017-01-01 04:00:00 +0000 UTC         0  Custom location
#
#          lat       lon  temp  visibility  dew_point  feels_like  ...  \
# 0  53.345035 -6.267261  5.39      9999.0       4.35        1.78  ...
# 1  53.345035 -6.267261  5.39      9999.0       4.35        2.28  ...
# 2  53.345035 -6.267261  5.39      9999.0       4.35        2.28  ...
# 3  53.345035 -6.267261  4.39      9999.0       3.36        0.04  ...
# 4  53.345035 -6.267261  4.39      9999.0       2.42        0.04  ...
#
#    wind_gust  rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  weather_id  \
# 0        NaN     2.30      NaN      NaN      NaN          75         501
# 1        NaN     1.51      NaN      NaN      NaN          75         501
# 2        NaN     0.64      NaN      NaN      NaN          75         500
# 3        NaN     0.17      NaN      NaN      NaN          75         500
# 4        NaN      NaN      NaN      NaN      NaN          75         803
#
#    weather_main  weather_description  weather_icon
# 0          Rain        moderate rain           10n
# 1          Rain        moderate rain           10n
# 2          Rain           light rain           10n
# 3          Rain           light rain           10n
# 4        Clouds        broken clouds           04n
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['dt', 'dt_iso', 'timezone', 'city_name', 'lat', 'lon', 'temp',
#        'visibility', 'dew_point', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'sea_level', 'grnd_level', 'humidity', 'wind_speed',
#        'wind_deg', 'wind_gust', 'rain_1h', 'rain_3h', 'snow_1h', 'snow_3h',
#        'clouds_all', 'weather_id', 'weather_main', 'weather_description',
#        'weather_icon'],
#       dtype='object')

# %%
df.shape
# Out:
# (27186, 28)

# %%
df.dtypes
# Out:
# dt                       int64
# dt_iso                  object
# timezone                 int64
# city_name               object
# lat                    float64
# lon                    float64
# temp                   float64
# visibility             float64
# dew_point              float64
# feels_like             float64
# temp_min               float64
# temp_max               float64
# pressure                 int64
# sea_level              float64
# grnd_level             float64
# humidity                 int64
# wind_speed             float64
# wind_deg                 int64
# wind_gust              float64
# rain_1h                float64
# rain_3h                float64
# snow_1h                float64
# snow_3h                float64
# clouds_all               int64
# weather_id               int64
# weather_main            object
# weather_description     object
# weather_icon            object
# dtype: object

# %% [markdown]
# ## Check if there are duplicate rows or columns

# %%
#remove whitespace in or around feature names
df.columns = df.columns.str.replace(' ', '')

#check to ensure whitespaces have been removed
df.columns
# Out:
# Index(['dt', 'dt_iso', 'timezone', 'city_name', 'lat', 'lon', 'temp',
#        'visibility', 'dew_point', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'sea_level', 'grnd_level', 'humidity', 'wind_speed',
#        'wind_deg', 'wind_gust', 'rain_1h', 'rain_3h', 'snow_1h', 'snow_3h',
#        'clouds_all', 'weather_id', 'weather_main', 'weather_description',
#        'weather_icon'],
#       dtype='object')

# %% [markdown]
# Only data for 2018 is required, so delete other times

# %% [markdown]
# ### Convert time format

# %%
df['dt_iso'] = pd.to_datetime(df['dt_iso'], format='%Y-%m-%d %H:%M:%S %z UTC')
df['dt_iso'] = df['dt_iso'].dt.strftime('%Y-%m-%d %H:%M:%S')
df['dt_iso'] = pd.to_datetime(df['dt_iso'])

# %%
df.head(5)
# Out:
#            dt              dt_iso  timezone        city_name        lat  \
# 0  1483228800 2017-01-01 00:00:00         0  Custom location  53.345035
# 1  1483232400 2017-01-01 01:00:00         0  Custom location  53.345035
# 2  1483236000 2017-01-01 02:00:00         0  Custom location  53.345035
# 3  1483239600 2017-01-01 03:00:00         0  Custom location  53.345035
# 4  1483243200 2017-01-01 04:00:00         0  Custom location  53.345035
#
#         lon  temp  visibility  dew_point  feels_like  ...  wind_gust  rain_1h  \
# 0 -6.267261  5.39      9999.0       4.35        1.78  ...        NaN     2.30
# 1 -6.267261  5.39      9999.0       4.35        2.28  ...        NaN     1.51
# 2 -6.267261  5.39      9999.0       4.35        2.28  ...        NaN     0.64
# 3 -6.267261  4.39      9999.0       3.36        0.04  ...        NaN     0.17
# 4 -6.267261  4.39      9999.0       2.42        0.04  ...        NaN      NaN
#
#    rain_3h  snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# 0      NaN      NaN      NaN          75         501          Rain
# 1      NaN      NaN      NaN          75         501          Rain
# 2      NaN      NaN      NaN          75         500          Rain
# 3      NaN      NaN      NaN          75         500          Rain
# 4      NaN      NaN      NaN          75         803        Clouds
#
#    weather_description  weather_icon
# 0        moderate rain           10n
# 1        moderate rain           10n
# 2           light rain           10n
# 3           light rain           10n
# 4        broken clouds           04n
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Delete data except for 2018

# %%
df.drop(df[~(df['dt_iso'].dt.year == 2018) ].index,inplace = True)

# %%
df.shape
# Out:
# (9060, 28)

# %%
df.head(5)
# Out:
#               dt              dt_iso  timezone        city_name        lat  \
# 9014  1514764800 2018-01-01 00:00:00         0  Custom location  53.345035
# 9015  1514768400 2018-01-01 01:00:00         0  Custom location  53.345035
# 9016  1514772000 2018-01-01 02:00:00         0  Custom location  53.345035
# 9017  1514775600 2018-01-01 03:00:00         0  Custom location  53.345035
# 9018  1514779200 2018-01-01 04:00:00         0  Custom location  53.345035
#
#            lon  temp  visibility  dew_point  feels_like  ...  wind_gust  \
# 9014 -6.267261  4.39      9999.0       2.26       -1.93  ...       18.0
# 9015 -6.267261  4.39      9999.0       2.26       -1.68  ...        NaN
# 9016 -6.267261  5.39      9999.0       2.40       -0.47  ...       18.5
# 9017 -6.267261  5.39      9999.0       2.40       -0.47  ...        NaN
# 9018 -6.267261  5.39      9999.0       2.40       -0.33  ...        NaN
#
#       rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  weather_id  \
# 9014      NaN      NaN      NaN      NaN          40         520
# 9015      NaN      NaN      NaN      NaN          75         520
# 9016      NaN      NaN      NaN      NaN          40         802
# 9017      NaN      NaN      NaN      NaN          40         802
# 9018      NaN      NaN      NaN      NaN          40         802
#
#       weather_main          weather_description  weather_icon
# 9014          Rain  light intensity shower rain           09n
# 9015          Rain  light intensity shower rain           09n
# 9016        Clouds             scattered clouds           03n
# 9017        Clouds             scattered clouds           03n
# 9018        Clouds             scattered clouds           03n
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Rename

# %%
df=df.rename(columns={'dt_iso':'day_hour'})

# %% [markdown]
# ## Check the constants column

# %%
#Check the data of category type to see if there is a constant column
df_columns = df.columns
features_card = list(df[df_columns].columns.values)

print('{0:35}  {1}'.format("Feature", "Unique Values"))
print('{0:35}  {1}'.format("-------", "--------------- \n"))

for c in df_columns:
    print('{0:35}  {1}'.format(c, str(len(df[c].unique()))))
# Out:
# Feature                              Unique Values
# -------                              ---------------
#
# dt                                   8760
# day_hour                             8760
# timezone                             2
# city_name                            1
# lat                                  1
# lon                                  1
# temp                                 639
# visibility                           36
# dew_point                            1109
# feels_like                           1507
# temp_min                             389
# temp_max                             529
# pressure                             63
# sea_level                            1
# grnd_level                           1
# humidity                             73
# wind_speed                           89
# wind_deg                             165
# wind_gust                            69
# rain_1h                              196
# rain_3h                              1
# snow_1h                              49
# snow_3h                              1
# clouds_all                           17
# weather_id                           23
# weather_main                         9
# weather_description                  24
# weather_icon                         17

# %% [markdown]
# From the above results we can see that city_name, lat, lon,sea_level,grnd_level,rain_3h,snow_3h are constant columns, so delete

# %%
df.drop(labels=['city_name','lat','lon','sea_level','grnd_level','rain_3h','snow_3h'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#               dt            day_hour  timezone  temp  visibility  dew_point  \
# 9014  1514764800 2018-01-01 00:00:00         0  4.39      9999.0       2.26
# 9015  1514768400 2018-01-01 01:00:00         0  4.39      9999.0       2.26
# 9016  1514772000 2018-01-01 02:00:00         0  5.39      9999.0       2.40
# 9017  1514775600 2018-01-01 03:00:00         0  5.39      9999.0       2.40
# 9018  1514779200 2018-01-01 04:00:00         0  5.39      9999.0       2.40
#
#       feels_like  temp_min  temp_max  pressure  ...  wind_speed  wind_deg  \
# 9014       -1.93      4.36      4.56       990  ...        12.9       240
# 9015       -1.68      4.36      4.56       990  ...        11.8       240
# 9016       -0.47      4.53      5.41       990  ...        12.4       240
# 9017       -0.47      4.53      5.41       990  ...        12.4       240
# 9018       -0.33      5.36      5.56       989  ...        11.8       240
#
#       wind_gust  rain_1h  snow_1h  clouds_all  weather_id  weather_main  \
# 9014       18.0      NaN      NaN          40         520          Rain
# 9015        NaN      NaN      NaN          75         520          Rain
# 9016       18.5      NaN      NaN          40         802        Clouds
# 9017        NaN      NaN      NaN          40         802        Clouds
# 9018        NaN      NaN      NaN          40         802        Clouds
#
#               weather_description weather_icon
# 9014  light intensity shower rain          09n
# 9015  light intensity shower rain          09n
# 9016             scattered clouds          03n
# 9017             scattered clouds          03n
# 9018             scattered clouds          03n
#
# [5 rows x 21 columns]

# %%
#check for duplicate rows

#Print the number of duplicates, without the original rows that were duplicated
print('Number of duplicate (excluding first) rows in the table is: ', df.duplicated().sum())

# Use "keep=False" to mark all duplicates as true, including the original rows that were duplicated.
print('Number of duplicate rows (including first) in the table is:', df[df.duplicated(keep=False)].shape[0])
# Out:
# Number of duplicate (excluding first) rows in the table is:  0
# Number of duplicate rows (including first) in the table is: 0

# %%
#check if there are any duplicate columns
# First transpose the df so columns become rows
dfT = df.T
print("Number of duplicate (excluding first) columns in the table is: ", dfT.duplicated().sum())
print("Number of duplicate (including first) columns in the table is: ",  dfT[dfT.duplicated(keep=False)].shape[0])

#.duplicate returns a Boolean Value so True will be returned if the column is a duplicate
print("Duplpicated columns will be True: ", dfT.duplicated())
# Out:
# Number of duplicate (excluding first) columns in the table is:  0
# Number of duplicate (including first) columns in the table is:  0
# Duplpicated columns will be True:  dt                     False
# day_hour               False
# timezone               False
# temp                   False
# visibility             False
# dew_point              False
# feels_like             False
# temp_min               False
# temp_max               False
# pressure               False
# humidity               False
# wind_speed             False
# wind_deg               False
# wind_gust              False
# rain_1h                False
# snow_1h                False
# clouds_all             False
# weather_id             False
# weather_main           False
# weather_description    False
# weather_icon           False
# dtype: bool

# %%
df.head(5)
# Out:
#               dt            day_hour  timezone  temp  visibility  dew_point  \
# 9014  1514764800 2018-01-01 00:00:00         0  4.39      9999.0       2.26
# 9015  1514768400 2018-01-01 01:00:00         0  4.39      9999.0       2.26
# 9016  1514772000 2018-01-01 02:00:00         0  5.39      9999.0       2.40
# 9017  1514775600 2018-01-01 03:00:00         0  5.39      9999.0       2.40
# 9018  1514779200 2018-01-01 04:00:00         0  5.39      9999.0       2.40
#
#       feels_like  temp_min  temp_max  pressure  ...  wind_speed  wind_deg  \
# 9014       -1.93      4.36      4.56       990  ...        12.9       240
# 9015       -1.68      4.36      4.56       990  ...        11.8       240
# 9016       -0.47      4.53      5.41       990  ...        12.4       240
# 9017       -0.47      4.53      5.41       990  ...        12.4       240
# 9018       -0.33      5.36      5.56       989  ...        11.8       240
#
#       wind_gust  rain_1h  snow_1h  clouds_all  weather_id  weather_main  \
# 9014       18.0      NaN      NaN          40         520          Rain
# 9015        NaN      NaN      NaN          75         520          Rain
# 9016       18.5      NaN      NaN          40         802        Clouds
# 9017        NaN      NaN      NaN          40         802        Clouds
# 9018        NaN      NaN      NaN          40         802        Clouds
#
#               weather_description weather_icon
# 9014  light intensity shower rain          09n
# 9015  light intensity shower rain          09n
# 9016             scattered clouds          03n
# 9017             scattered clouds          03n
# 9018             scattered clouds          03n
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Check for missing values

# %%
# Prepare %missing column
cols = df.columns
columns_perc_missing  = 100 * (df[cols].isnull().sum()/df.shape[0])
#category_columns_perc_missing

# Store the values in a dataframe
df_perc_missing = pd.DataFrame(columns_perc_missing, columns=['%missing'])
df_perc_missing
# Out:
#                       %missing
# dt                    0.000000
# day_hour              0.000000
# timezone              0.000000
# temp                  0.000000
# visibility            0.441501
# dew_point             0.000000
# feels_like            0.000000
# temp_min              0.000000
# temp_max              0.000000
# pressure              0.000000
# humidity              0.000000
# wind_speed            0.000000
# wind_deg              0.000000
# wind_gust            90.298013
# rain_1h              80.485651
# snow_1h              99.139073
# clouds_all            0.000000
# weather_id            0.000000
# weather_main          0.000000
# weather_description   0.000000
# weather_icon          0.000000

# %% [markdown]
# From the above results it can be observed that the %missing value of snow_1h is relatively high, but this is a key feature of the analysis results and is therefore not removed.

# %%
dupldate= df[df['day_hour'].duplicated()]

# %%
dupldate
# Out:
#                dt            day_hour  timezone   temp  visibility  dew_point  \
# 9092   1515042000 2018-01-04 05:00:00         0   4.39      5000.0       3.36
# 9094   1515045600 2018-01-04 06:00:00         0   5.39      6000.0       4.35
# 9216   1515481200 2018-01-09 07:00:00         0   5.39      6000.0       4.35
# 9218   1515484800 2018-01-09 08:00:00         0   5.39      8000.0       4.35
# 9220   1515488400 2018-01-09 09:00:00         0   5.39      5000.0       4.35
# ...           ...                 ...       ...    ...         ...        ...
# 17865  1545562800 2018-12-23 11:00:00         0   7.44      8000.0       7.29
# 17867  1545566400 2018-12-23 12:00:00         0   7.58      9999.0       7.43
# 17869  1545570000 2018-12-23 13:00:00         0   7.58      7000.0       7.43
# 17871  1545573600 2018-12-23 14:00:00         0   7.48      9999.0       7.33
# 18010  1546070400 2018-12-29 08:00:00         0  11.34      9999.0      10.25
#
#        feels_like  temp_min  temp_max  pressure  ...  wind_speed  wind_deg  \
# 9092         0.04      4.36      4.56       988  ...         6.2       120
# 9094         0.16      5.36      5.56       985  ...         9.8       140
# 9216         0.62      5.36      5.56      1003  ...         8.2       160
# 9218        -0.33      5.36      5.56      1002  ...        11.8       140
# 9220         0.29      5.36      5.56      1002  ...         9.3       140
# ...           ...       ...       ...       ...  ...         ...       ...
# 17865        5.72      7.05      7.56      1016  ...         2.6        60
# 17867        6.28      7.36      7.96      1017  ...         2.1        30
# 17869        5.88      7.36      7.96      1017  ...         2.6       350
# 17871        5.42      6.99      7.96      1017  ...         3.1       350
# 18010       10.96     10.88     11.56      1028  ...         8.2       260
#
#        wind_gust  rain_1h  snow_1h  clouds_all  weather_id  weather_main  \
# 9092         NaN     1.03      NaN          75         501          Rain
# 9094         NaN     0.59      NaN          75         311       Drizzle
# 9216        13.4     0.54      NaN          75         300       Drizzle
# 9218         NaN     0.26      NaN          75         500          Rain
# 9220         NaN     0.35      NaN          75         500          Rain
# ...          ...      ...      ...         ...         ...           ...
# 17865        NaN     0.76      NaN          75         500          Rain
# 17867        NaN     1.02      NaN          75         501          Rain
# 17869        NaN     1.02      NaN          75         501          Rain
# 17871        NaN     0.25      NaN          75         300       Drizzle
# 18010        NaN     0.13      NaN          75         500          Rain
#
#            weather_description weather_icon
# 9092             moderate rain          10n
# 9094          rain and drizzle          09n
# 9216   light intensity drizzle          09n
# 9218                light rain          10n
# 9220                light rain          10d
# ...                        ...          ...
# 17865               light rain          10d
# 17867            moderate rain          10d
# 17869            moderate rain          10d
# 17871  light intensity drizzle          09d
# 18010               light rain          10n
#
# [300 rows x 21 columns]

# %% [markdown]
# As you can see from the above results there are 300 duplicates and therefore need to be removed

# %%
df.drop(df[df['day_hour'].duplicated()].index,inplace = True)

# %%
dupldate= df[df['day_hour'].duplicated()]

# %%
dupldate
# Out:
# Empty DataFrame
# Columns: [dt, day_hour, timezone, temp, visibility, dew_point, feels_like, temp_min, temp_max, pressure, humidity, wind_speed, wind_deg, wind_gust, rain_1h, snow_1h, clouds_all, weather_id, weather_main, weather_description, weather_icon]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['rain_1h']=df['rain_1h'].fillna(value=0)

# %%
df['snow_1h']=df['snow_1h'].fillna(value=0)

# %%
df.shape
# Out:
# (8760, 21)

# %%
df.to_csv('weatherData_cleaned.csv', index_label=False)
